# %% [markdown]
# # WeatherPy
# ### This Jupyter Notebook file will visualize the weather of 500+ cities across the world of varying distance from the equator.
# To accomplish this, the notebook utilizes a simple Python library, the OpenWeatherMap API, and a little common sense to create a representative model of weather across world cities.
# The notebook will build a series of scatter plots to showcase the following relationships:
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# %% [markdown]
# ## _Results and Analysis_
# * Temperature increases the closer one gets to the equator (i.e. latitude 0 degrees). The hottest part of the planet appears to be near the equator.
# * Humidity and cloudiness do not appear to share any relationship with latitude. That is fairly surprising as I would have assumed there would have been a relationship between latitude and humidity.
# * Moreover, wind speed does not appear to be related to latitude as the wind speed appears to be fairly low regardless of the latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate City List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Check the city count to confirm sufficient count (should be greater than 500)
if len(cities) > 500:
    print("There is a sufficient number of cities for our analysis.")
# Out:
# There is a sufficient number of cities for our analysis.

# %% [markdown]
# ## Perform API calls

# %%
 # OpenWeatherMap API Key
api_key = api_keys.api_key

# Save config information for openweathermap API
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Create an "extracts" object to get the temperature, latitude,
# and longitude in each city
temp =[]
lat = []
lon = []
hum = []
cloud = []
wind = []

# store results in lists
for city in cities:
    current_json = requests.get(query_url + city).json()
    try:
        temp.append(float(current_json["main"]["temp"]))
        lat.append(float(current_json["coord"]["lat"]))
        lon.append(float(current_json["coord"]["lon"]))
        hum.append(float(current_json["main"]["humidity"]))
        cloud.append(float(current_json["clouds"]["all"]))
        wind.append(float(current_json["wind"]["speed"]))
        # print city number and city name
        print(f'{cities.index(city)}: Loading in weather information for {city}...')

    except:
        temp.append(None)
        lat.append(None)
        lon.append(None)
        hum.append(None)
        cloud.append(None)
        wind.append(None)
        # print city number and city name
        print(f'{cities.index(city)}: Could not load in weather information for {city}!!!')


## Create a Pandas DataFrame with the results
city_results_dict = {
    "City": cities,
    "Temperature (F)": temp,
    "Latitude": lat,
    "Longitude": lon,
    "Humidity": hum,
    "Cloudiness (%)": cloud,
    "Wind Speed (mph)": wind
}

city_results_df = pd.DataFrame(city_results_dict)
city_results_df.head(5)
# Out:
# 0: Loading in weather information for lukovetskiy...
# 1: Loading in weather information for yar-sale...
# 2: Loading in weather information for constitucion...
# 3: Loading in weather information for atuona...
# 4: Loading in weather information for la palma...
# 5: Loading in weather information for provideniya...
# 6: Loading in weather information for petropavlovsk-kamchatskiy...
# 7: Loading in weather information for banyo...
# 8: Loading in weather information for alice springs...
# 9: Loading in weather information for hilo...
# 10: Loading in weather information for vryheid...
# 11: Could not load in weather information for paradwip!!!
# 12: Loading in weather information for alofi...
# 13: Loading in weather information for avarua...
# 14: Loading in weather information for itarema...
# 15: Loading in weather information for kovdor...
# 16: Loading in weather information for san pedro...
# 17: Loading in weather information for tuktoyaktuk...
# 18: Loading in weather information for punta arenas...
# 19: Loading in weather information for saskylakh...
# 20: Loading in weather information for busselton...
# 21: Loading in weather information for jamestown...
# 22: Loading in weather information for kodiak...
# 23: Could not load in weather information for belushya guba!!!
# 24: Loading in weather information for jaisalmer...
# 25: Could not load in weather information for attawapiskat!!!
# 26: Could not load in weather information for illoqqortoormiut!!!
# 27: Loading in weather information for chicama...
# 28: Could not load in weather information for gardan diwal!!!
# 29: Loading in weather information for la esperanza...
# 30: Loading in weather information for saint george...
# 31: Loading in weather information for kruisfontein...
# 32: Could not load in weather information for nizhneyansk!!!
# 33: Loading in weather information for shenjiamen...
# 34: Loading in weather information for rikitea...
# 35: Loading in weather information for bilma...
# 36: Could not load in weather information for sataua!!!
# 37: Loading in weather information for san ramon...
# 38: Loading in weather information for talavera...
# 39: Loading in weather information for bilibino...
# 40: Loading in weather information for albany...
# 41: Loading in weather information for portland...
# 42: Could not load in weather information for maneadero!!!
# 43: Loading in weather information for latung...
# 44: Loading in weather information for grindavik...
# 45: Loading in weather information for khatanga...
# 46: Loading in weather information for carnarvon...
# 47: Loading in weather information for hobyo...
# 48: Loading in weather information for rock sound...
# 49: Loading in weather information for mataura...
# 50: Could not load in weather information for palabuhanratu!!!
# 51: Loading in weather information for unecha...
# 52: Loading in weather information for kapaa...
# 53: Loading in weather information for diego de almagro...
# 54: Loading in weather information for amahai...
# 55: Loading in weather information for pevek...
# 56: Loading in weather information for castro...
# 57: Loading in weather information for yulara...
# 58: Loading in weather information for vila franca do campo...
# 59: Loading in weather information for mar del plata...
# 60: Loading in weather information for port elizabeth...
# 61: Loading in weather information for luderitz...
# 62: Loading in weather information for malanje...
# 63: Loading in weather information for marquette...
# 64: Loading in weather information for karratha...
# 65: Loading in weather information for ushuaia...
# 66: Loading in weather information for mundargi...
# 67: Loading in weather information for bredasdorp...
# 68: Loading in weather information for sitka...
# 69: Loading in weather information for okha...
# 70: Could not load in weather information for amderma!!!
# 71: Loading in weather information for san jose...
# 72: Loading in weather information for norman wells...
# 73: Loading in weather information for baculin...
# 74: Loading in weather information for pangnirtung...
# 75: Loading in weather information for balikpapan...
# 76: Loading in weather information for beloha...
# 77: Loading in weather information for christchurch...
# 78: Loading in weather information for nandgaon...
# 79: Could not load in weather information for geresk!!!
# 80: Loading in weather information for ambulu...
# 81: Loading in weather information for ostrovnoy...
# 82: Loading in weather information for bluff...
# 83: Loading in weather information for chuy...
# 84: Loading in weather information for mogok...
# 85: Could not load in weather information for taolanaro!!!
# 86: Loading in weather information for yeppoon...
# 87: Loading in weather information for bethel...
# 88: Loading in weather information for saint-francois...
# 89: Loading in weather information for bundaberg...
# 90: Loading in weather information for sabinas hidalgo...
# 91: Loading in weather information for hithadhoo...
# 92: Loading in weather information for tiksi...
# 93: Loading in weather information for kirakira...
# 94: Loading in weather information for mahanoro...
# 95: Loading in weather information for deputatskiy...
# 96: Loading in weather information for madikeri...
# 97: Loading in weather information for agadez...
# 98: Loading in weather information for asheville...
# 99: Loading in weather information for nikolskoye...
# 100: Loading in weather information for turek...
# 101: Loading in weather information for voh...
# 102: Loading in weather information for muyezerskiy...
# 103: Loading in weather information for barrow...
# 104: Loading in weather information for hobart...
# 105: Loading in weather information for warrington...
# 106: Loading in weather information for tirano...
# 107: Loading in weather information for hualmay...
# 108: Loading in weather information for hermanus...
# 109: Could not load in weather information for olafsvik!!!
# 110: Loading in weather information for san martin...
# 111: Loading in weather information for wasilla...
# 112: Loading in weather information for qaanaaq...
# 113: Loading in weather information for kipini...
# 114: Loading in weather information for tilichiki...
# 115: Loading in weather information for cherskiy...
# 116: Loading in weather information for vaini...
# 117: Loading in weather information for comodoro rivadavia...
# 118: Loading in weather information for bud...
# 119: Loading in weather information for airai...
# 120: Loading in weather information for sal rei...
# 121: Loading in weather information for le port...
# 122: Loading in weather information for cidreira...
# 123: Loading in weather information for cape town...
# 124: Loading in weather information for torbay...
# 125: Loading in weather information for ola...
# 126: Loading in weather information for bereznehuvate...
# 127: Loading in weather information for pouebo...
# 128: Loading in weather information for ribeira grande...
# 129: Loading in weather information for geraldton...
# 130: Could not load in weather information for pemangkat!!!
# 131: Loading in weather information for taksimo...
# 132: Loading in weather information for butaritari...
# 133: Loading in weather information for anchorage...
# 134: Loading in weather information for mercedes...
# 135: Could not load in weather information for vaitupu!!!
# 136: Loading in weather information for isangel...
# 137: Loading in weather information for hasaki...
# 138: Loading in weather information for la fria...
# 139: Loading in weather information for walvis bay...
# 140: Loading in weather information for puerto ayora...
# 141: Loading in weather information for troitsko-pechorsk...
# 142: Loading in weather information for beringovskiy...
# 143: Loading in weather information for kibaya...
# 144: Loading in weather information for northam...
# 145: Could not load in weather information for barentsburg!!!
# 146: Loading in weather information for kununurra...
# 147: Loading in weather information for monte patria...
# 148: Loading in weather information for victoria...
# 149: Loading in weather information for riom...
# 150: Loading in weather information for ginir...
# 151: Loading in weather information for vikhorevka...
# 152: Loading in weather information for laguna...
# 153: Loading in weather information for avera...
# 154: Loading in weather information for xushan...
# 155: Loading in weather information for saldanha...
# 156: Loading in weather information for seoul...
# 157: Loading in weather information for georgetown...
# 158: Loading in weather information for grants pass...
# 159: Loading in weather information for kyzyl-suu...
# 160: Loading in weather information for ponta do sol...
# 161: Loading in weather information for samarai...
# 162: Loading in weather information for atyashevo...
# 163: Loading in weather information for ishigaki...
# 164: Could not load in weather information for goteborg!!!
# 165: Loading in weather information for batagay-alyta...
# 166: Loading in weather information for yellowknife...
# 167: Loading in weather information for san quintin...
# 168: Loading in weather information for bambous virieux...
# 169: Loading in weather information for puerto palomas...
# 170: Could not load in weather information for tasbuget!!!
# 171: Loading in weather information for kedrovyy...
# 172: Loading in weather information for norrtalje...
# 173: Loading in weather information for cabinda...
# 174: Loading in weather information for mount gambier...
# 175: Loading in weather information for coquimbo...
# 176: Loading in weather information for ormara...
# 177: Loading in weather information for esperance...
# 178: Loading in weather information for necochea...
# 179: Loading in weather information for peniche...
# 180: Loading in weather information for verkhoyansk...
# 181: Loading in weather information for namwala...
# 182: Loading in weather information for sisimiut...
# 183: Loading in weather information for nizhniy kuranakh...
# 184: Loading in weather information for emerald...
# 185: Loading in weather information for buraydah...
# 186: Loading in weather information for belmonte...
# 187: Loading in weather information for sunagawa...
# 188: Loading in weather information for flinders...
# 189: Loading in weather information for nanortalik...
# 190: Loading in weather information for roseto degli abruzzi...
# 191: Loading in weather information for kodinar...
# 192: Loading in weather information for nabire...
# 193: Could not load in weather information for akyab!!!
# 194: Loading in weather information for arraial do cabo...
# 195: Loading in weather information for balabac...
# 196: Loading in weather information for banda aceh...
# 197: Loading in weather information for lagoa...
# 198: Loading in weather information for socoltenango...
# 199: Loading in weather information for kavaratti...
# 200: Loading in weather information for bandarbeyla...
# 201: Loading in weather information for road town...
# 202: Loading in weather information for nemuro...
# 203: Loading in weather information for gizo...
# 204: Loading in weather information for dikson...
# 205: Loading in weather information for taoudenni...
# 206: Loading in weather information for mackenzie...
# 207: Could not load in weather information for marcona!!!
# 208: Loading in weather information for santa cruz cabralia...
# 209: Loading in weather information for yarada...
# 210: Loading in weather information for cockburn town...
# 211: Loading in weather information for port hedland...
# 212: Loading in weather information for bambanglipuro...
# 213: Loading in weather information for dondo...
# 214: Loading in weather information for sarkand...
# 215: Loading in weather information for port blair...
# 216: Loading in weather information for wagar...
# 217: Could not load in weather information for maridi!!!
# 218: Loading in weather information for leningradskiy...
# 219: Loading in weather information for port alfred...
# 220: Loading in weather information for mehamn...
# 221: Loading in weather information for vao...
# 222: Loading in weather information for sinazongwe...
# 223: Loading in weather information for mazatlan...
# 224: Loading in weather information for upata...
# 225: Loading in weather information for severodvinsk...
# 226: Loading in weather information for ahipara...
# 227: Loading in weather information for henties bay...
# 228: Loading in weather information for fort nelson...
# 229: Loading in weather information for awbari...
# 230: Loading in weather information for sao filipe...
# 231: Loading in weather information for cayenne...
# 232: Loading in weather information for glendive...
# 233: Loading in weather information for mahebourg...
# 234: Loading in weather information for ceres...
# 235: Loading in weather information for moju...
# 236: Loading in weather information for saint-philippe...
# 237: Loading in weather information for palmer...
# 238: Could not load in weather information for saryshagan!!!
# 239: Could not load in weather information for kushmurun!!!
# 240: Loading in weather information for antsohihy...
# 241: Loading in weather information for mogocha...
# 242: Loading in weather information for perth...
# 243: Loading in weather information for yilan...
# 244: Loading in weather information for itoman...
# 245: Loading in weather information for richards bay...
# 246: Could not load in weather information for mullaitivu!!!
# 247: Loading in weather information for lorengau...
# 248: Loading in weather information for sapa...
# 249: Loading in weather information for sur...
# 250: Loading in weather information for thompson...
# 251: Loading in weather information for eregli...
# 252: Loading in weather information for rocha...
# 253: Loading in weather information for dalvik...
# 254: Loading in weather information for touros...
# 255: Loading in weather information for balakhta...
# 256: Loading in weather information for banjar...
# 257: Loading in weather information for aksu...
# 258: Loading in weather information for nouadhibou...
# 259: Loading in weather information for codrington...
# 260: Loading in weather information for narsaq...
# 261: Loading in weather information for klaksvik...
# 262: Loading in weather information for aksarka...
# 263: Could not load in weather information for grand river south east!!!
# 264: Loading in weather information for phan thiet...
# 265: Loading in weather information for east london...
# 266: Loading in weather information for upernavik...
# 267: Loading in weather information for makakilo city...
# 268: Loading in weather information for buenos aires...
# 269: Loading in weather information for viedma...
# 270: Could not load in weather information for mys shmidta!!!
# 271: Loading in weather information for las vegas...
# 272: Loading in weather information for namibe...
# 273: Loading in weather information for dunedin...
# 274: Loading in weather information for kamina...
# 275: Could not load in weather information for tumannyy!!!
# 276: Loading in weather information for paso de carrasco...
# 277: Loading in weather information for batemans bay...
# 278: Loading in weather information for pisco...
# 279: Loading in weather information for kutahya...
# 280: Loading in weather information for tezu...
# 281: Loading in weather information for karasjok...
# 282: Loading in weather information for baijiantan...
# 283: Loading in weather information for alampur...
# 284: Loading in weather information for opunake...
# 285: Loading in weather information for tiznit...
# 286: Loading in weather information for la ronge...
# 287: Loading in weather information for brae...
# 288: Loading in weather information for aleksandrov gay...
# 289: Loading in weather information for tazovskiy...
# 290: Could not load in weather information for labutta!!!
# 291: Loading in weather information for kargasok...
# 292: Loading in weather information for vestmannaeyjar...
# 293: Loading in weather information for iqaluit...
# 294: Loading in weather information for marsa matruh...
# 295: Loading in weather information for mwene-ditu...
# 296: Loading in weather information for kaka...
# 297: Loading in weather information for ozinki...
# 298: Could not load in weather information for kristiinankaupunki!!!
# 299: Could not load in weather information for ngukurr!!!
# 300: Loading in weather information for umm kaddadah...
# 301: Loading in weather information for new norfolk...
# 302: Loading in weather information for sao domingos...
# 303: Loading in weather information for linqiong...
# 304: Loading in weather information for harnosand...
# 305: Loading in weather information for namatanai...
# 306: Loading in weather information for katsuura...
# 307: Could not load in weather information for sorvag!!!
# 308: Loading in weather information for pangkalanbuun...
# 309: Loading in weather information for wellington...
# 310: Loading in weather information for rancho grande...
# 311: Loading in weather information for hadejia...
# 312: Loading in weather information for george town...
# 313: Loading in weather information for velika kladusa...
# 314: Loading in weather information for abnub...
# 315: Loading in weather information for udomlya...
# 316: Loading in weather information for mallow...
# 317: Loading in weather information for hovd...
# 318: Loading in weather information for maltahohe...
# 319: Could not load in weather information for gangotri!!!
# 320: Loading in weather information for nome...
# 321: Loading in weather information for ketchikan...
# 322: Loading in weather information for dhrangadhra...
# 323: Loading in weather information for tubuala...
# 324: Loading in weather information for bridlington...
# 325: Loading in weather information for fortuna...
# 326: Loading in weather information for jizan...
# 327: Loading in weather information for parli...
# 328: Loading in weather information for the pas...
# 329: Loading in weather information for rio grande...
# 330: Loading in weather information for college...
# 331: Loading in weather information for salalah...
# 332: Loading in weather information for zahesi...
# 333: Loading in weather information for tasiilaq...
# 334: Loading in weather information for abaza...
# 335: Loading in weather information for dingle...
# 336: Could not load in weather information for toungoo!!!
# 337: Loading in weather information for ancud...
# 338: Could not load in weather information for satitoa!!!
# 339: Loading in weather information for talnakh...
# 340: Loading in weather information for labytnangi...
# 341: Loading in weather information for nuuk...
# 342: Loading in weather information for seybaplaya...
# 343: Loading in weather information for hami...
# 344: Loading in weather information for tateyama...
# 345: Loading in weather information for ucluelet...
# 346: Loading in weather information for vostok...
# 347: Loading in weather information for severo-kurilsk...
# 348: Loading in weather information for baykit...
# 349: Loading in weather information for aitape...
# 350: Loading in weather information for negombo...
# 351: Loading in weather information for bahir dar...
# 352: Loading in weather information for svetlaya...
# 353: Loading in weather information for marawi...
# 354: Loading in weather information for parangan...
# 355: Loading in weather information for moen...
# 356: Loading in weather information for manicore...
# 357: Loading in weather information for huarmey...
# 358: Loading in weather information for rawson...
# 359: Loading in weather information for wawa...
# 360: Loading in weather information for moranbah...
# 361: Loading in weather information for verkhnyaya inta...
# 362: Loading in weather information for teseney...
# 363: Loading in weather information for panjab...
# 364: Loading in weather information for guerrero negro...
# 365: Loading in weather information for zhiryatino...
# 366: Loading in weather information for capao da canoa...
# 367: Loading in weather information for coahuayana...
# 368: Loading in weather information for vestmanna...
# 369: Loading in weather information for hall...
# 370: Loading in weather information for san patricio...
# 371: Loading in weather information for keith...
# 372: Loading in weather information for havelock...
# 373: Loading in weather information for ayan...
# 374: Loading in weather information for longyearbyen...
# 375: Could not load in weather information for tabarqah!!!
# 376: Could not load in weather information for buqayq!!!
# 377: Loading in weather information for ovalle...
# 378: Loading in weather information for shache...
# 379: Could not load in weather information for urumqi!!!
# 380: Loading in weather information for caucaia...
# 381: Loading in weather information for saint-pierre...
# 382: Loading in weather information for saint-augustin...
# 383: Loading in weather information for buluang...
# 384: Loading in weather information for emporia...
# 385: Loading in weather information for kaitangata...
# 386: Loading in weather information for lokosovo...
# 387: Loading in weather information for sorong...
# 388: Loading in weather information for mocuba...
# 389: Loading in weather information for hvide sande...
# 390: Loading in weather information for udgir...
# 391: Loading in weather information for hay river...
# 392: Loading in weather information for fairbanks...
# 393: Loading in weather information for mattru...
# 394: Loading in weather information for el alto...
# 395: Loading in weather information for teknaf...
# 396: Loading in weather information for chipinge...
# 397: Loading in weather information for tigil...
# 398: Loading in weather information for tual...
# 399: Loading in weather information for hambantota...
# 400: Could not load in weather information for rungata!!!
# 401: Loading in weather information for cabedelo...
# 402: Loading in weather information for kutum...
# 403: Could not load in weather information for samusu!!!
# 404: Loading in weather information for leh...
# 405: Could not load in weather information for tsihombe!!!
# 406: Loading in weather information for aklavik...
# 407: Loading in weather information for gubkinskiy...
# 408: Loading in weather information for rosetta...
# 409: Loading in weather information for egvekinot...
# 410: Loading in weather information for missoula...
# 411: Loading in weather information for pingxiang...
# 412: Loading in weather information for te anau...
# 413: Loading in weather information for kaeo...
# 414: Loading in weather information for alugan...
# 415: Loading in weather information for fare...
# 416: Loading in weather information for salta...
# 417: Loading in weather information for kathmandu...
# 418: Loading in weather information for santa isabel do rio negro...
# 419: Loading in weather information for okhotsk...
# 420: Loading in weather information for port shepstone...
# 421: Loading in weather information for quelimane...
# 422: Loading in weather information for dargaville...
# 423: Loading in weather information for eureka...
# 424: Loading in weather information for sidhi...
# 425: Loading in weather information for lundazi...
# 426: Loading in weather information for laredo...
# 427: Loading in weather information for padang...
# 428: Loading in weather information for husavik...
# 429: Loading in weather information for poykovskiy...
# 430: Loading in weather information for talaya...
# 431: Loading in weather information for los llanos de aridane...
# 432: Loading in weather information for west bay...
# 433: Loading in weather information for abu samrah...
# 434: Loading in weather information for nkoteng...
# 435: Loading in weather information for raudeberg...
# 436: Loading in weather information for kurilsk...
# 437: Loading in weather information for nieuw amsterdam...
# 438: Loading in weather information for siniscola...
# 439: Could not load in weather information for armacao dos buzios!!!
# 440: Loading in weather information for inyonga...
# 441: Could not load in weather information for bossembele!!!
# 442: Could not load in weather information for bengkulu!!!
# 443: Loading in weather information for formosa...
# 444: Loading in weather information for goderich...
# 445: Could not load in weather information for bargal!!!
# 446: Loading in weather information for hashtrud...
# 447: Loading in weather information for noumea...
# 448: Loading in weather information for beriu...
# 449: Loading in weather information for sao joao da barra...
# 450: Loading in weather information for zhangjiakou...
# 451: Loading in weather information for skelleftea...
# 452: Loading in weather information for tokur...
# 453: Loading in weather information for juneau...
# 454: Loading in weather information for zeya...
# 455: Loading in weather information for saint-joseph...
# 456: Loading in weather information for esso...
# 457: Could not load in weather information for atka!!!
# 458: Loading in weather information for oromocto...
# 459: Loading in weather information for mpika...
# 460: Loading in weather information for krutikha...
# 461: Loading in weather information for mount isa...
# 462: Loading in weather information for salinopolis...
# 463: Loading in weather information for surt...
# 464: Loading in weather information for alta...
# 465: Loading in weather information for teya...
# 466: Loading in weather information for yerbogachen...
# 467: Could not load in weather information for vreed en hoop!!!
# 468: Loading in weather information for niono...
# 469: Loading in weather information for nsanje...
# 470: Loading in weather information for hofn...
# 471: Loading in weather information for clyde river...
# 472: Loading in weather information for kotli loharan...
# 473: Loading in weather information for muros...
# 474: Loading in weather information for panacan...
# 475: Loading in weather information for bagotville...
# 476: Loading in weather information for olinda...
# 477: Loading in weather information for saint-leu...
# 478: Could not load in weather information for nguiu!!!
# 479: Loading in weather information for krynychky...
# 480: Loading in weather information for smidovich...
# 481: Loading in weather information for umea...
# 482: Loading in weather information for angra dos reis...
# 483: Loading in weather information for watertown...
# 484: Loading in weather information for broken hill...
# 485: Could not load in weather information for sentyabrskiy!!!
# 486: Loading in weather information for turayf...
# 487: Loading in weather information for pires do rio...
# 488: Loading in weather information for sao felix do xingu...
# 489: Loading in weather information for katobu...
# 490: Loading in weather information for arman...
# 491: Loading in weather information for half moon bay...
# 492: Loading in weather information for takoradi...
# 493: Loading in weather information for mandan...
# 494: Loading in weather information for diapaga...
# 495: Loading in weather information for grand gaube...
# 496: Could not load in weather information for khomeynishahr!!!
# 497: Loading in weather information for shingu...
# 498: Loading in weather information for boddam...
# 499: Loading in weather information for kavieng...
# 500: Loading in weather information for ruwi...
# 501: Could not load in weather information for krasnoselkup!!!
# 502: Loading in weather information for batsfjord...
# 503: Could not load in weather information for wad madani!!!
# 504: Loading in weather information for tigre...
# 505: Loading in weather information for znamenskoye...
# 506: Loading in weather information for sibolga...
# 507: Loading in weather information for orotukan...
# 508: Loading in weather information for lavrentiya...
# 509: Loading in weather information for el fuerte...
# 510: Loading in weather information for parksepa...
# 511: Loading in weather information for braganca...
# 512: Loading in weather information for honavar...
# 513: Loading in weather information for balkanabat...
# 514: Could not load in weather information for babanusah!!!
# 515: Loading in weather information for fortuna foothills...
# 516: Loading in weather information for xai-xai...
# 517: Loading in weather information for echirolles...
# 518: Could not load in weather information for wa!!!
# 519: Loading in weather information for lebu...
# 520: Loading in weather information for gorahun...
# 521: Loading in weather information for kieta...
# 522: Could not load in weather information for abu jubayhah!!!
# 523: Loading in weather information for erenhot...
# 524: Loading in weather information for flin flon...
# 525: Loading in weather information for ambovombe...
# 526: Loading in weather information for nicoya...
# 527: Loading in weather information for kahului...
# 528: Loading in weather information for springbok...
# 529: Loading in weather information for omsukchan...
# 530: Loading in weather information for minsk...
# 531: Loading in weather information for nizhniy tsasuchey...
# 532: Loading in weather information for vardo...
# 533: Loading in weather information for caravelas...
# 534: Loading in weather information for sinnamary...
# 535: Loading in weather information for lerwick...
# 536: Loading in weather information for akniste...
# 537: Could not load in weather information for fort saint john!!!
# 538: Loading in weather information for bulls...
# 539: Loading in weather information for nusaybin...
# 540: Loading in weather information for ilulissat...
# 541: Loading in weather information for arlit...
# 542: Loading in weather information for margate...
# 543: Loading in weather information for key west...
# 544: Loading in weather information for khora...
# 545: Loading in weather information for labuhan...
# 546: Loading in weather information for fereydun kenar...
# 547: Loading in weather information for camargo...
# 548: Loading in weather information for tura...
# 549: Loading in weather information for jumla...
# 550: Loading in weather information for madimba...
# 551: Loading in weather information for bandar-e lengeh...
# 552: Loading in weather information for axim...
# 553: Loading in weather information for poum...
# 554: Loading in weather information for baicheng...
# 555: Loading in weather information for araouane...
# 556: Could not load in weather information for inderborskiy!!!
# 557: Could not load in weather information for karaul!!!
# 558: Loading in weather information for preobrazheniye...
# 559: Loading in weather information for calvia...
# 560: Loading in weather information for naze...
# 561: Loading in weather information for bonavista...
# 562: Loading in weather information for port lincoln...
# 563: Loading in weather information for dalbandin...
# 564: Loading in weather information for maputo...
# 565: Loading in weather information for moroni...
# 566: Loading in weather information for cairns...
# 567: Loading in weather information for royan...
# 568: Loading in weather information for shalakusha...
# 569: Loading in weather information for sistranda...
# 570: Loading in weather information for jurm...
# 571: Loading in weather information for kidal...
# 572: Loading in weather information for nongan...
# 573: Loading in weather information for steamboat springs...
# 574: Could not load in weather information for khonsar!!!
# 575: Loading in weather information for alice town...
# 576: Loading in weather information for arteaga...
# 577: Loading in weather information for erzin...
# 578: Loading in weather information for lyuban...
# 579: Loading in weather information for porto novo...
# 580: Loading in weather information for muroto...
# 581: Loading in weather information for san nicolas...
# 582: Loading in weather information for honningsvag...
# 583: Loading in weather information for garowe...
# 584: Loading in weather information for koraput...
# 585: Loading in weather information for gorontalo...
# 586: Loading in weather information for el dorado...
# 587: Loading in weather information for maningrida...
# 588: Loading in weather information for ostersund...
# 589: Loading in weather information for xucheng...
# 590: Could not load in weather information for louisbourg!!!
# 591: Loading in weather information for scarborough...
# 592: Loading in weather information for haradok...
# 593: Loading in weather information for coos bay...
# 594: Loading in weather information for baruun-urt...
# 595: Loading in weather information for aldan...
# 596: Loading in weather information for jertih...
# 597: Could not load in weather information for mme!!!
# 598: Loading in weather information for panzhihua...
# 599: Loading in weather information for jaypur...
# 600: Loading in weather information for cascais...
# 601: Loading in weather information for krasnyy kommunar...
# 602: Loading in weather information for apeldoorn...
# 603: Could not load in weather information for bolungarvik!!!
# 604: Loading in weather information for verkh-chebula...
# 605: Loading in weather information for lisala...
# 606: Loading in weather information for sindou...
# 607: Loading in weather information for nouakchott...
# 608: Loading in weather information for yantal...
# 609: Loading in weather information for itatiba...
# 610: Loading in weather information for auki...
# 611: Loading in weather information for kannur...
# 612: Loading in weather information for ouango...
# 613: Loading in weather information for zhigansk...
# 614: Could not load in weather information for lolua!!!
# 615: Could not load in weather information for thilogne!!!
# 616: Loading in weather information for denpasar...
# 617: Loading in weather information for atikokan...
# 618: Could not load in weather information for milingimbi!!!
# 619: Loading in weather information for besancon...
# 620: Loading in weather information for iracoubo...
# 621: Loading in weather information for udarnyy...
# 622: Loading in weather information for djenne...
# 623: Loading in weather information for usinsk...
# 624: Loading in weather information for oranjestad...
# 625: Loading in weather information for sioux lookout...
# 626: Loading in weather information for honiara...
# 627: Loading in weather information for ampanihy...
# 628: Loading in weather information for chara...
# 629: Could not load in weather information for rolim de moura!!!
# 630: Loading in weather information for mecca...
#            City  Temperature (F)  Latitude  Longitude  Humidity  \
# 0   lukovetskiy            51.80     64.29      41.92     100.0
# 1      yar-sale            42.24     66.83      70.83     100.0
# 2  constitucion            60.80     23.99    -104.67      87.0
# 3        atuona            79.68     -9.80    -139.03     100.0
# 4      la palma            72.93      5.36     -74.39      85.0
#
#    Cloudiness (%)  Wind Speed (mph)
# 0            20.0              2.59
# 1            44.0             12.77
# 2            90.0              8.05
# 3             0.0             16.80
# 4            36.0              2.71

# %% [markdown]
# ## Plot Latitude Relationships with Weather Information

# %%
# plot 1: Temperature (F) vs. Latitude
plt1_x_axis = city_results_df["Latitude"]
plt1_y_axis = city_results_df["Temperature (F)"]

plt1 = plt.scatter(plt1_x_axis, plt1_y_axis, color="blue", 
                    label="Cities", alpha=0.5)

# set x and y axis labels
plt.xlabel('Latitude', fontweight="bold")
plt.ylabel('Temperature (F)', fontweight="bold")

# give the graph a title and legend
plt.title('Temperature (F) vs. Latitude [08/29/2018]', fontsize=16, fontweight="bold")
plt.legend(loc="best", fancybox=True)

# save image of plot to png file
plt.savefig('/Users/finianoneill/Desktop/UCB_Bootcamp/Homework/Week6_APIs_HW/weatherpy/Outputs/temp_vs_latitude.png')

plt.show()

# %%
# plot 2: Humidity (%) vs. Latitude
plt2_x_axis = city_results_df["Latitude"]
plt2_y_axis = city_results_df["Humidity"]

plt2 = plt.scatter(plt2_x_axis, plt2_y_axis, color="green", 
                    label="Cities", alpha=0.5)

# set x and y axis labels
plt.xlabel('Latitude', fontweight="bold")
plt.ylabel('Humidity', fontweight="bold")

# give the graph a title and legend
plt.title('Humidity vs. Latitude [08/29/2018]', fontsize=16, fontweight="bold")
plt.legend(loc="best", fancybox=True)

# save image of plot to png file
plt.savefig('/Users/finianoneill/Desktop/UCB_Bootcamp/Homework/Week6_APIs_HW/weatherpy/Outputs/humidity_vs_latitude.png')

plt.show()

# %%
# plot 3: Cloudiness (%) vs. Latitude
plt3_x_axis = city_results_df["Latitude"]
plt3_y_axis = city_results_df["Cloudiness (%)"]

plt3 = plt.scatter(plt3_x_axis, plt3_y_axis, color="purple", 
                    label="Cities", alpha=0.5)

# set x and y axis labels
plt.xlabel('Latitude', fontweight="bold")
plt.ylabel('Cloudiness (%)', fontweight="bold")

# give the graph a title and legend
plt.title('Cloudiness (%) vs. Latitude [08/29/2018]', fontsize=16, fontweight="bold")
plt.legend(loc="best", fancybox=True)

# save image of plot to png file
plt.savefig('/Users/finianoneill/Desktop/UCB_Bootcamp/Homework/Week6_APIs_HW/weatherpy/Outputs/cloudiness_vs_latitude.png')

plt.show()

# %%
# plt1 = scatter plot of Temperature (F) vs. Latitude
# plt2 = scatter plot of Humidity (%) vs. Latitude
# plt3 = scatter plot of Cloudiness (%) vs. Latitude
# plt4 = scatter plot of Wind Speed (mph) vs. Latitude
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=False)

# plot 4: Wind Speed (mph) vs. Latitude
plt4_x_axis = city_results_df["Latitude"]
plt4_y_axis = city_results_df["Wind Speed (mph)"]

plt4 = plt.scatter(plt4_x_axis, plt4_y_axis, color="red", 
                    label="Cities", alpha=0.5)

# set x and y axis labels
plt.xlabel('Latitude', fontweight="bold")
plt.ylabel('Wind Speed (mph)', fontweight="bold")

# give the graph a title and legend
plt.title('Wind Speed (mph) vs. Latitude [08/29/2018]', fontsize=16, fontweight="bold")
plt.legend(loc="best", fancybox=True)

# save image of plot to png file
plt.savefig('/Users/finianoneill/Desktop/UCB_Bootcamp/Homework/Week6_APIs_HW/weatherpy/Outputs/windspeed_vs_latitude.png')

plt.show()

# %% [markdown]
# ## Export Data and Results to Output Files

# %%
# export csv of the data frame with all city and weather information
city_results_df.to_csv("Outputs/city_weather_info.csv")
